# %% [markdown]
# # 00_colab_setup.ipynb
#
# This notebook sets up the Colab environment by:
# - Mounting Google Drive
# - Navigating to the project root
# - Cloning the GitHub repo (if not already present)
#
# Run this once at the beginning of every session.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/llm-finetuning-project
# Out:
# /content/drive/MyDrive/llm-finetuning-project

# %%
# !ls
# Out:
# data  faiss_store  models  qa_pairs

# %%
# !git clone https://github.com/samyakshrestha/llm-finetuning-summarizer.git
# Out:
# Cloning into 'llm-finetuning-summarizer'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 11 (delta 1), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.
# Resolving deltas: 100% (1/1), done.

# %%
# !ls llm-finetuning-summarizer
# Out:
# data  deployment  LICENSE  notebooks  project_plan.md  README.md  scripts

# %%
# %cd /content/drive/MyDrive/llm-finetuning-project/llm-finetuning-summarizer/notebooks
# Out:
# /content/drive/MyDrive/llm-finetuning-project/llm-finetuning-summarizer/notebooks

# %%
from google.colab import files
files.download('00_colab_setup.ipynb')
